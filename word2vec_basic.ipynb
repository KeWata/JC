# %%
import collections
import math
import os
import random
import zipfile
import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return(filename)
# Here we use text8 corpus
filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a string.
def read_data(filename):
    f = zipfile.ZipFile(filename)
    for name in f.namelist():
        return f.read(name).split()
    f.close()
words = read_data(filename)
print('Data size', len(words))
# Out:
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], (b'the', 1061396), (b'of', 593677), (b'and', 416629), (b'one', 411764)]
# Sample data [5243, 3081, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
    print(batch[i], '->', labels[i, 0])
    print(reverse_dictionary[batch[i]], '->', reverse_dictionary[labels[i, 0]])
# Out:
# 3081 -> 5243
# b'originated' -> b'anarchism'
# 3081 -> 12
# b'originated' -> b'as'
# 12 -> 6
# b'as' -> b'a'
# 12 -> 3081
# b'as' -> b'originated'
# 6 -> 195
# b'a' -> b'term'
# 6 -> 12
# b'a' -> b'as'
# 195 -> 6
# b'term' -> b'a'
# 195 -> 2
# b'term' -> b'of'

# %%
# Step 4: Build and train a skip-gram model.
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64    # Number of negative examples to sample.

# %%
graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
                tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
                tf.truncated_normal([vocabulary_size, embedding_size],
                                                        stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
            tf.nn.nce_loss(nce_weights, nce_biases, embed, train_labels,
                                         num_sampled, vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
            normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
            valid_embeddings, normalized_embeddings, transpose_b=True)

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    tf.initialize_all_variables().run()
    print("Initialized")

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(
                batch_size, num_skips, skip_window)
        feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  283.6796875
# Nearest to b'five': b'natal', b'rapid', b'businessweek', b'hooker', b'saunders', b'prosper', b'sworn', b'destiny',
# Nearest to b'that': b'inject', b'pcbs', b'astronauts', b'paracelsus', b'smalley', b'occurs', b'breeze', b'eurystheus',
# Nearest to b'to': b'broadbent', b'feeder', b'os', b'emeritus', b'newsted', b'mv', b'contested', b'fgth',
# Nearest to b'over': b'thumbs', b'corvette', b'kyo', b'angli', b'mosley', b'thermometers', b'tempting', b'redman',
# Nearest to b'these': b'discernable', b'inspire', b'toro', b'institution', b'slates', b'upholding', b'cylinders', b'presentations',
# Nearest to b'while': b'researchers', b'recipient', b'aperture', b'identifies', b'wg', b'carneiro', b'labrador', b'casing',
# Nearest to b'world': b'slam', b'oversaw', b'capitalism', b'gre', b'goodbye', b'gothic', b'rzeczypospolitej', b'rossby',
# Nearest to b'which': b'typefaces', b'marley', b'mustelids', b'mycological', b'milosevic', b'demanded', b'proven', b'rotate',
# Nearest to b'known': b'barbara', b'genealogy', b'recorder', b'concisely', b'spell', b'vindicated', b'zoster', b'tiff',
# Nearest to b'so': b'emulators', b'egyptian', b'ghetto', b'groningen', b'dundas', b'cotton', b'fries', b'stoppage',
# Nearest to b'see': b'peopled', b'oxymoron', b'bafta', b'postmodernist', b'premiership', b'textbooks', b'amato', b'tleilaxu',
# Nearest to b'by': b'dabbled', b'techstep', b'storytelling', b'adorning', b'winter', b'maribor', b'kapital', b'parser',
# Nearest to b'nine': b'quarks', b'doctorate', b'teutons', b'wireless', b'frustrations', b'aside', b'peripheries', b'motorcycle',
# Nearest to b'they': b'initiator', b'helen', b'subliminal', b'avoiding', b'shackleton', b'pendergast', b'hidalgo', b'codasyl',
# Nearest to b'have': b'burn', b'problematic', b'percentages', b'military', b'aspirated', b'immigrant', b'burdensome', b'inaccuracy',
# Nearest to b'b': b'sasha', b'darker', b'monrovia', b'ndez', b'headless', b'truce', b'gastrointestinal', b'attrition',
# Average loss at step  2000 :  113.978978468
# Average loss at step  4000 :  51.9841738997
# Average loss at step  6000 :  33.9793843108
# Average loss at step  8000 :  23.4362822061
# Average loss at step  10000 :  17.8393477831
# Nearest to b'five': b'nine', b'reginae', b'zero', b'rapid', b'seven', b'two', b'cl', b'aarhus',
# Nearest to b'that': b'agave', b'occurs', b'operation', b'astronauts', b'and', b'vs', b'alumnus', b'which',
# Nearest to b'to': b'and', b'in', b'pronunciation', b'plata', b'on', b'one', b'austin', b'for',
# Nearest to b'over': b'thumbs', b'gb', b'jurisdictions', b'circle', b'instead', b'mathbf', b'cc', b'of',
# Nearest to b'these': b'institution', b'engines', b'reaching', b'inspire', b'hickory', b'stylization', b'hope', b'numerals',
# Nearest to b'while': b'researchers', b'recipient', b'identifies', b'reginae', b'are', b'federal', b'decrease', b'emancipation',
# Nearest to b'world': b'capitalism', b'slam', b'top', b'drink', b'divided', b'manufacturers', b'u', b'civil',
# Nearest to b'which': b'austin', b'a', b'reginae', b'proven', b'that', b'rotate', b'song', b'and',
# Nearest to b'known': b'barbara', b'andrew', b'police', b'progression', b'prior', b'well', b'spell', b'andr',
# Nearest to b'so': b'clockwork', b'cotton', b'egyptian', b'ghetto', b'alif', b'theorem', b'alternatively', b'nihon',
# Nearest to b'see': b'fam', b'premiership', b'and', b'fraud', b'organisms', b'fermented', b'austin', b'stating',
# Nearest to b'by': b'and', b'analogue', b'in', UNK, b'fao', b'zero', b'winter', b'for',
# Nearest to b'nine': b'zero', b'reginae', b'austin', b'victoriae', b'phi', b'gland', b'eight', b'agave',
# Nearest to b'they': b'helen', b'austin', b'unicode', b'stanley', b'commonly', b'and', b'strain', b'coast',
# Nearest to b'have': b'had', b'burn', b'military', b'problematic', b'dispelling', b'aut', b'microscopy', b'vs',
# Nearest to b'b': b'helped', b'sodium', b'urn', b'landlord', b'apollo', b'integration', b'wars', b'gastrointestinal',
# Average loss at step  12000 :  14.1935182633
# Average loss at step  14000 :  11.8249177884
# Average loss at step  16000 :  9.84004863679
# Average loss at step  18000 :  8.60999404228
# Average loss at step  20000 :  7.75395377648
# Nearest to b'five': b'zero', b'eight', b'two', b'nine', b'seven', b'four', b'three', b'six',
# Nearest to b'that': b'which', b'incompressible', b'occurs', b'agave', b'and', b'often', b'yang', b'it',
# Nearest to b'to': b'for', b'and', b'into', b'pronunciation', b'nine', b'breeders', b'in', b'with',
# Nearest to b'over': b'thumbs', b'subkey', b'nine', b'of', b'circle', b'jurisdictions', b'four', b'gb',
# Nearest to b'these': b'institution', b'reaching', b'hickory', b'engines', b'inspire', b'the', b'toro', b'birkenau',
# Nearest to b'while': b'recipient', b'are', b'researchers', b'identifies', b'bataan', b'hardly', b'federal', b'soups',
# Nearest to b'world': b'capitalism', b'slam', b'top', b'u', b'drink', b'oversaw', b'gothic', b'manufacturers',
# Nearest to b'which': b'that', b'and', b'a', b'this', b'also', b'agouti', b'comrade', b'two',
# Nearest to b'known': b'barbara', b'well', b'andrew', b'genealogy', b'synonymous', b'adder', b'unceasing', b'progression',
# Nearest to b'so': b'agouti', b'clockwork', b'cotton', b'emulators', b'ghetto', b'dasyprocta', b'theorem', b'moab',
# Nearest to b'see': b'and', b'fam', b'peopled', b'affinities', b'fraud', b'premiership', b'dasyprocta', b'stating',
# Nearest to b'by': b'in', b'for', b'with', b'was', b'analogue', b'and', b'is', b'from',
# Nearest to b'nine': b'eight', b'seven', b'six', b'zero', b'four', b'agouti', b'five', b'three',
# Nearest to b'they': b'he', b'we', b'helen', b'stanley', b'it', b'austin', b'agouti', b'garter',
# Nearest to b'have': b'had', b'be', b'problematic', b'burn', b'arminian', b'junction', b'binding', b'military',
# Nearest to b'b': b'd', b'and', b'ndez', b'sodium', b'landlord', b'polyhedra', b'gastrointestinal', b'urn',
# Average loss at step  22000 :  7.19404087245
# Average loss at step  24000 :  6.90193417513
# Average loss at step  26000 :  6.66622156429
# Average loss at step  28000 :  6.24197294092
# Average loss at step  30000 :  6.11250959694
# Nearest to b'five': b'eight', b'four', b'six', b'seven', b'three', b'nine', b'zero', b'two',
# Nearest to b'that': b'which', b'incompressible', b'often', b'it', b'occurs', b'agp', b'yang', b'agave',
# Nearest to b'to': b'for', b'into', b'peptide', b'can', b'agouti', b'in', b'breeders', b'would',
# Nearest to b'over': b'thumbs', b'adventist', b'amalthea', b'angli', b'abet', b'subkey', b'word', b'aba',
# Nearest to b'these': b'institution', b'hickory', b'reaching', b'the', b'which', b'inspire', b'engines', b'birkenau',
# Nearest to b'while': b'are', b'researchers', b'identifies', b'recipient', b'lauderdale', b'and', b'is', b'hardly',
# Nearest to b'world': b'capitalism', b'rzeczypospolitej', b'drink', b'oversaw', b'slam', b'gothic', b'top', b'civil',
# Nearest to b'which': b'that', b'this', b'abet', b'also', b'it', b'vfa', b'agouti', b'and',
# Nearest to b'known': b'well', b'barbara', b'genealogy', b'andrew', b'oilers', b'a', b'synonymous', b'humid',
# Nearest to b'so': b'emulators', b'almighty', b'agouti', b'clockwork', b'cotton', b'ghetto', b'hamas', b'dasyprocta',
# Nearest to b'see': b'reuptake', b'aba', b'and', b'aorta', b'affinities', b'lossy', b'stating', b'fam',
# Nearest to b'by': b'in', b'with', b'was', b'for', b'and', b'from', b'as', b'at',
# Nearest to b'nine': b'eight', b'seven', b'six', b'five', b'four', b'zero', b'three', b'agouti',
# Nearest to b'they': b'he', b'we', b'it', b'stanley', b'who', b'there', b'helen', b'austin',
# Nearest to b'have': b'had', b'be', b'has', b'intifada', b'binding', b'akh', b'are', b'junction',
# Nearest to b'b': b'd', b'ndez', b'sodium', b'gastrointestinal', b'landlord', b'eucalyptus', b'bondage', b'and',
# Average loss at step  32000 :  5.85200631142
# Average loss at step  34000 :  5.88573936355
# Average loss at step  36000 :  5.69202812111
# Average loss at step  38000 :  5.27196695888
# Average loss at step  40000 :  5.44548431718
# Nearest to b'five': b'four', b'three', b'seven', b'six', b'eight', b'zero', b'two', b'nine',
# Nearest to b'that': b'which', b'it', b'draught', b'incompressible', b'agp', b'often', b'this', b'occurs',
# Nearest to b'to': b'for', b'into', b'not', b'agouti', b'peptide', b'nine', b'can', b'breeders',
# Nearest to b'over': b'thumbs', b'adventist', b'subkey', b'amalthea', b'angli', b'abet', b'eight', b'nine',
# Nearest to b'these': b'institution', b'many', b'which', b'some', b'hickory', b'reaching', b'mathias', b'six',
# Nearest to b'while': b'and', b'are', b'lauderdale', b'researchers', b'identifies', b'is', b'recipient', b'fidonet',
# Nearest to b'world': b'capitalism', b'rzeczypospolitej', b'oversaw', b'drink', b'top', b'slam', b'gothic', b'civil',
# Nearest to b'which': b'that', b'this', b'it', b'also', b'and', b'abet', b'what', b'agouti',
# Nearest to b'known': b'well', b'barbara', b'such', b'genealogy', b'oilers', b'humid', b'synonymous', b'reverend',
# Nearest to b'so': b'emulators', b'almighty', b'agouti', b'clockwork', b'cotton', b'nuke', b'ghetto', b'dasyprocta',
# Nearest to b'see': b'reuptake', b'aba', b'aorta', b'affinities', b'stating', b'fam', b'pauling', b'dict',
# Nearest to b'by': b'was', b'with', b'in', b'be', b'is', b'for', b'toaster', b'from',
# Nearest to b'nine': b'eight', b'seven', b'six', b'zero', b'five', b'four', b'three', b'agouti',
# Nearest to b'they': b'he', b'we', b'it', b'there', b'who', b'stanley', b'not', b'guderian',
# Nearest to b'have': b'had', b'has', b'be', b'are', b'were', b'intifada', b'binding', b'akh',
# Nearest to b'b': b'd', b'ndez', UNK, b'bondage', b'gastrointestinal', b'landlord', b'sodium', b'eucalyptus',
# Average loss at step  42000 :  5.32708163977
# Average loss at step  44000 :  5.366867118
# Average loss at step  46000 :  5.28836132121
# Average loss at step  48000 :  5.02898227215
# Average loss at step  50000 :  5.15128495026
# Nearest to b'five': b'four', b'six', b'three', b'seven', b'eight', b'two', b'zero', b'nine',
# Nearest to b'that': b'which', b'perfective', b'but', b'draught', b'this', b'incompressible', b'thibetanus', b'often',
# Nearest to b'to': b'can', b'could', b'nine', b'into', b'would', b'not', b'for', b'peptide',
# Nearest to b'over': b'thumbs', b'angli', b'subkey', b'adventist', b'amalthea', b'eight', b'abet', b'kicker',
# Nearest to b'these': b'many', b'some', b'institution', b'which', b'reaching', b'hickory', b'both', b'mathias',
# Nearest to b'while': b'and', b'lauderdale', b'is', b'researchers', b'but', b'fidonet', b'identifies', b'are',
# Nearest to b'world': b'capitalism', b'rzeczypospolitej', b'oversaw', b'drink', b'top', b'slam', b'civil', b'gothic',
# Nearest to b'which': b'that', b'this', b'also', b'what', b'it', b'one', b'there', b'who',
# Nearest to b'known': b'well', b'such', b'barbara', b'genealogy', b'oilers', b'humid', b'reverend', b'synonymous',
# Nearest to b'so': b'emulators', b'almighty', b'agouti', b'nuke', b'cotton', b'clockwork', b'ted', b'corrupts',
# Nearest to b'see': b'reuptake', b'aorta', b'affinities', b'pauling', b'stating', b'lossy', b'granville', b'aba',
# Nearest to b'by': b'was', b'be', b'with', b'from', b'in', b'for', b'through', b'is',
# Nearest to b'nine': b'eight', b'seven', b'six', b'four', b'zero', b'five', b'three', b'agouti',
# Nearest to b'they': b'he', b'we', b'there', b'it', b'who', b'guderian', b'stanley', b'garter',
# Nearest to b'have': b'had', b'has', b'be', b'are', b'were', b'intifada', b'akh', b'tana',
# Nearest to b'b': b'd', b'ndez', UNK, b'bondage', b'eucalyptus', b'recruited', b'sasha', b'aquila',
# Average loss at step  52000 :  5.1564573859
# Average loss at step  54000 :  5.11146028602
# Average loss at step  56000 :  5.07320655394
# Average loss at step  58000 :  5.08767324853
# Average loss at step  60000 :  4.95936771864
# Nearest to b'five': b'four', b'six', b'three', b'eight', b'seven', b'zero', b'nine', b'two',
# Nearest to b'that': b'which', b'this', b'but', b'perfective', b'draught', b'what', b'it', b'when',
# Nearest to b'to': b'not', b'could', b'can', b'agouti', b'nine', b'for', b'would', b'marmoset',
# Nearest to b'over': b'thumbs', b'subkey', b'through', b'angli', b'into', b'marmoset', b'cebus', b'in',
# Nearest to b'these': b'some', b'many', b'institution', b'which', b'microcebus', b'hickory', b'reaching', b'both',
# Nearest to b'while': b'marmoset', b'michelob', b'when', b'lauderdale', b'ssbn', b'fidonet', b'but', b'and',
# Nearest to b'world': b'capitalism', b'rzeczypospolitej', b'oversaw', b'civil', b'drink', b'gothic', b'u', b'century',
# Nearest to b'which': b'that', b'this', b'what', b'also', b'it', b'but', b'who', b'one',
# Nearest to b'known': b'well', b'such', b'barbara', b'genealogy', b'oilers', b'used', b'humid', b'reverend',
# Nearest to b'so': b'emulators', b'almighty', b'agouti', b'nuke', b'clockwork', b'cotton', b'dasyprocta', b'ted',
# Nearest to b'see': b'reuptake', b'aorta', b'michelob', b'affinities', b'callithrix', b'ssbn', b'lossy', b'pauling',
# Nearest to b'by': b'be', b'with', b'was', b'through', b'in', b'been', b'analogue', b'from',
# Nearest to b'nine': b'eight', b'six', b'seven', b'four', b'five', b'zero', b'three', b'agouti',
# Nearest to b'they': b'we', b'he', b'there', b'it', b'who', b'guderian', b'not', b'stanley',
# Nearest to b'have': b'had', b'has', b'are', b'be', b'were', b'akh', b'intifada', b'binding',
# Nearest to b'b': b'd', b'callithrix', b'ndez', b'bebox', b'marmoset', b'bondage', b'sasha', b'eucalyptus',
# Average loss at step  62000 :  4.78743344378
# Average loss at step  64000 :  4.79129784644
# Average loss at step  66000 :  4.99540717852
# Average loss at step  68000 :  4.91967685628
# Average loss at step  70000 :  4.77860413897
# Nearest to b'five': b'four', b'six', b'eight', b'seven', b'three', b'nine', b'zero', b'two',
# Nearest to b'that': b'which', b'this', b'what', b'but', b'draught', b'perfective', b'however', b'incompressible',
# Nearest to b'to': b'can', b'could', b'peptide', b'for', b'agouti', b'would', b'not', b'marmoset',
# Nearest to b'over': b'thumbs', b'through', b'angli', b'subkey', b'into', b'circle', b'six', b'cebus',
# Nearest to b'these': b'some', b'many', b'which', b'institution', b'they', b'all', b'reaching', b'there',
# Nearest to b'while': b'and', b'thaler', b'michelob', b'when', b'marmoset', b'are', b'ssbn', b'but',
# Nearest to b'world': b'rzeczypospolitej', b'capitalism', b'oversaw', b'gothic', b'u', b'heal', b'century', b'drink',
# Nearest to b'which': b'that', b'this', b'what', b'also', b'but', b'it', b'and', b'who',
# Nearest to b'known': b'well', b'such', b'used', b'reverend', b'genealogy', b'oilers', b'ssbn', b'humid',
# Nearest to b'so': b'emulators', b'almighty', b'agouti', b'nuke', b'clockwork', b'cotton', b'ted', b'corrupts',
# Nearest to b'see': b'reuptake', b'callithrix', b'and', b'granville', b'aorta', b'affinities', b'ssbn', b'arbiter',
# Nearest to b'by': b'was', b'be', b'in', b'with', b'from', b'through', b'been', b'toaster',
# Nearest to b'nine': b'eight', b'seven', b'six', b'five', b'four', b'zero', b'three', b'ssbn',
# Nearest to b'they': b'we', b'he', b'there', b'it', b'who', b'you', b'not', b'these',
# Nearest to b'have': b'had', b'has', b'were', b'are', b'be', b'akh', b'intifada', b'anemometers',
# Nearest to b'b': b'd', b'bebox', b'ndez', b'callithrix', b'bondage', UNK, b'seven', b'marmoset',
# Average loss at step  72000 :  4.79904509366
# Average loss at step  74000 :  4.78570501691
# Average loss at step  76000 :  4.89088632894
# Average loss at step  78000 :  4.78120026147
# Average loss at step  80000 :  4.82363991928
# Nearest to b'five': b'four', b'six', b'seven', b'eight', b'three', b'nine', b'zero', b'two',
# Nearest to b'that': b'which', b'what', b'this', b'however', b'perfective', b'but', b'when', b'incompressible',
# Nearest to b'to': b'peptide', b'agouti', b'can', b'nine', b'microsite', b'michelob', b'for', b'would',
# Nearest to b'over': b'thumbs', b'through', b'into', b'subkey', b'angli', b'around', b'circle', b'four',
# Nearest to b'these': b'many', b'some', b'which', b'all', b'such', b'they', b'there', b'both',
# Nearest to b'while': b'and', b'when', b'michelob', b'thaler', b'but', b'although', b'marmoset', b'ssbn',
# Nearest to b'world': b'oversaw', b'rzeczypospolitej', b'capitalism', b'century', b'u', b'gothic', b'heal', b'drink',
# Nearest to b'which': b'this', b'that', b'what', b'also', b'it', b'but', b'there', b'michelob',
# Nearest to b'known': b'well', b'such', b'used', b'reverend', b'ssbn', b'humid', b'aquila', b'synonymous',
# Nearest to b'so': b'emulators', b'almighty', b'agouti', b'nuke', b'clockwork', b'cotton', b'dasyprocta', b'corrupts',
# Nearest to b'see': b'reuptake', b'callithrix', b'granville', b'aorta', b'ssbn', b'arbiter', b'pauling', b'michelob',
# Nearest to b'by': b'was', b'be', b'from', b'through', b'with', b'in', b'toaster', b'when',
# Nearest to b'nine': b'eight', b'seven', b'six', b'five', b'four', b'zero', b'three', b'agouti',
# Nearest to b'they': b'we', b'he', b'there', b'it', b'who', b'you', b'not', b'these',
# Nearest to b'have': b'had', b'has', b'were', b'are', b'be', b'intifada', b'iit', b'akh',
# Nearest to b'b': b'd', UNK, b'ndez', b'bebox', b'callithrix', b'seven', b'bondage', b'marmoset',
# Average loss at step  82000 :  4.81504238963
# Average loss at step  84000 :  4.78072181869
# Average loss at step  86000 :  4.74020142341
# Average loss at step  88000 :  4.68030916965
# Average loss at step  90000 :  4.75002574873
# Nearest to b'five': b'four', b'seven', b'eight', b'six', b'three', b'nine', b'two', b'zero',
# Nearest to b'that': b'which', b'what', b'however', b'this', b'but', b'incompressible', b'draught', b'perfective',
# Nearest to b'to': b'through', b'can', b'would', b'could', b'peptide', b'agouti', b'breeders', b'marmoset',
# Nearest to b'over': b'through', b'into', b'thumbs', b'subkey', b'around', b'angli', b'circle', b'under',
# Nearest to b'these': b'some', b'many', b'which', b'they', b'all', b'both', b'such', b'several',
# Nearest to b'while': b'when', b'although', b'and', b'but', b'michelob', b'including', b'thaler', b'ssbn',
# Nearest to b'world': b'oversaw', b'century', b'gothic', b'drink', b'heal', b'rzeczypospolitej', b'capitalism', b'top',
# Nearest to b'which': b'that', b'this', b'what', b'also', b'but', b'it', b'and', b'there',
# Nearest to b'known': b'well', b'used', b'such', b'reverend', b'synonymous', b'humid', b'aquila', b'ssbn',
# Nearest to b'so': b'emulators', b'almighty', b'nuke', b'agouti', b'clockwork', b'cotton', b'felt', b'seaport',
# Nearest to b'see': b'reuptake', b'callithrix', b'granville', b'aorta', b'ssbn', b'arbiter', b'lossy', b'michelob',
# Nearest to b'by': b'through', b'was', b'be', b'toaster', b'from', b'under', b'been', b'when',
# Nearest to b'nine': b'eight', b'seven', b'six', b'five', b'four', b'zero', b'agouti', b'ssbn',
# Nearest to b'they': b'we', b'he', b'there', b'it', b'you', b'who', b'not', b'these',
# Nearest to b'have': b'had', b'has', b'were', b'are', b'be', b'iit', b'akh', b'intifada',
# Nearest to b'b': b'd', b'bebox', b'callithrix', b'ndez', b'bondage', b'four', b'seven', b'marmoset',
# Average loss at step  92000 :  4.72250676298
# Average loss at step  94000 :  4.61393376863
# Average loss at step  96000 :  4.73029731953
# Average loss at step  98000 :  4.61556032377
# Average loss at step  100000 :  4.67359762084
# Nearest to b'five': b'four', b'six', b'seven', b'eight', b'three', b'zero', b'two', b'nine',
# Nearest to b'that': b'which', b'what', b'however', b'this', b'but', b'draught', b'perfective', b'it',
# Nearest to b'to': b'could', b'can', b'would', b'will', b'through', b'marmoset', b'not', b'agouti',
# Nearest to b'over': b'through', b'into', b'thumbs', b'around', b'subkey', b'circle', b'angli', b'under',
# Nearest to b'these': b'some', b'many', b'all', b'such', b'they', b'both', b'several', b'which',
# Nearest to b'while': b'when', b'although', b'but', b'and', b'michelob', b'are', b'thaler', b'including',
# Nearest to b'world': b'century', b'oversaw', b'rzeczypospolitej', b'u', b'gothic', b'heal', b'capitalism', b'drink',
# Nearest to b'which': b'that', b'this', b'what', b'but', b'also', b'it', b'both', b'one',
# Nearest to b'known': b'well', b'used', b'such', b'aquila', b'ssbn', b'reverend', b'synonymous', b'humid',
# Nearest to b'so': b'emulators', b'almighty', b'nuke', b'agouti', b'clockwork', b'cotton', b'corrupts', b'seaport',
# Nearest to b'see': b'reuptake', b'callithrix', b'and', b'seven', b'arbiter', b'ssbn', b'granville', b'affinities',
# Nearest to b'by': b'through', b'be', b'was', b'been', b'toaster', b'under', b'from', b'with',
# Nearest to b'nine': b'eight', b'seven', b'six', b'five', b'four', b'zero', b'agouti', b'ssbn',
# Nearest to b'they': b'we', b'he', b'there', b'you', b'it', b'these', b'who', b'not',
# Nearest to b'have': b'had', b'has', b'were', b'are', b'be', b'intifada', b'include', b'iit',
# Nearest to b'b': b'd', b'bebox', b'callithrix', b'ndez', b'marmoset', b'bondage', b'aquila', b'urn',

# %%
# Step 6: Visualize the embeddings.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label, xy=(x, y),
                                 xytext=(5, 2),
                                 textcoords='offset points',
                                 ha='right',
                                 va='bottom')

    plt.show()

# %%
from sklearn.manifold import TSNE
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 300
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels)
